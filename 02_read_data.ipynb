# %% [markdown]
# READ DATA IN PANDAS

# %%
import pandas as pd

# %%
# ==========================
# CSV FILE READ KARNE KA CODE
# ==========================

df = pd.read_csv("G:\downloads\student_marks.csv")

print(df)
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
# 5       Annu      F  05-04-1988     45       87         52       89       55
# 6      pooja      F  04-05-1987     55       64         61       58       75
# 7     Ritesh      M  25-05-1989     54       76         87       56       25
# 8      Farha      F  12-08-1990     55       63         89       75       78
# 9     Mukesh      M  02-09-1989     96       46         77       83       58
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# ...

# %%
# CSV file read karne ke liye use hota hai
# pd.read_csv()

# Excel file (.xlsx, .xls) read karne ke liye
# pd.read_excel()

# JSON data read karne ke liye
# pd.read_json()

# HTML table read karne ke liye
# pd.read_html()

# SQL query ka result read karne ke liye
# pd.read_sql()

# Database ki table read karne ke liye
# pd.read_sql_table()

# SQL query execute karke data read karne ke liye
# pd.read_sql_query()

# XML file read karne ke liye
# pd.read_xml()

# Parquet format file read karne ke liye
# pd.read_parquet()

# Feather format file read karne ke liye
# pd.read_feather()

# Pickle file read karne ke liye
# pd.read_pickle()

# HDF5 file read karne ke liye
# pd.read_hdf()

# SAS dataset read karne ke liye
# pd.read_sas()

# Stata file read karne ke liye
# pd.read_stata()

# Fixed-width text file read karne ke liye
# pd.read_fwf()

# Tab-separated ya delimited text file read karne ke liye
# pd.read_table()

# Clipboard se data read karne ke liye
# pd.read_clipboard()

# ORC format file read karne ke liye
# pd.read_orc()
