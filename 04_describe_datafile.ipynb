# %% [markdown]
# DESCRIBE OUR DATA FILE

# %%
import pandas as pd

# %%
#ye ek csv file hai jisse hum read kar rahe hai
csv_file = pd.read_csv("G:\downloads\student_marks.csv")

# %%
"""csv_file.describe() se hum csv file ke data ka summary dekh sakte hai, jaise ki
1.count
2.mean
3.std
4.min
5.25%
6.50%
7.75%
8.max
ye sabhi statistics hume csv file ke data ke baare me jankari dete hai, jaise ki data ka average, data ka spread, data ka minimum aur maximum value, etc.
"""
csv_file.describe()
# Out:
#            Maths    Physics  Chemistry    Biology
# count  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  64.700000
# std    19.460501  20.661559  14.000397  26.998148
# min    25.000000  45.000000  52.000000  21.000000
# 25%    54.250000  56.250000  65.000000  54.250000
# 50%    55.000000  70.000000  78.000000  66.500000
# 75%    70.750000  93.750000  86.750000  87.000000
# max    96.000000  96.000000  89.000000  96.000000
