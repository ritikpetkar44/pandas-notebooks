# %%
import pandas as pd

# %%
#ye ek csv file hai jisse hum read kar rahe hai
csv_file = pd.read_csv("G:\downloads\student_marks.csv")

# %%
"""csv_file.info()
 se hum csv file ke data ke baare me jankari milti hai, jaise ki
1. data ke columns ka naam(name, age, marks, etc.)
2. data ke columns ka data type(int, float, object, string)
3. data ke columns ka non-null count
4. data ke size
5. data ke memory usage
"""
csv_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10 non-null     object
#  1   Gender      10 non-null     object
#  2   DOB         10 non-null     object
#  3   Maths       10 non-null     int64
#  4   Physics     10 non-null     int64
#  5   Chemistry   10 non-null     int64
#  6   Biology     10 non-null     int64
# dtypes: int64(4), object(3)
# memory usage: 688.0+ bytes
