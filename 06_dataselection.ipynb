# %% [markdown]
# DATA SELECTION

# %%
import pandas as pd

# %%
#ye ek csv file hai jisse hum read kar rahe hai
csv_file = pd.read_csv("G:\downloads\student_marks.csv")

# %%
#jab kabhi ek perticular column ko dekhna ho to hum us column ka naam likh ke usko access kar sakte hai
#only one column raha toh wo ek pandas series ban jayega
#csv_file["Biology"] se hum Biology column ko access kar sakte hai
csv_file["Biology"]
# Out:
# 0    21
# 1    90
# 2    95
# 3    54
# 4    96
# 5    55
# 6    75
# 7    25
# 8    78
# 9    58
# Name: Biology, dtype: int64

# %%
 #ye ek pandas series hai
#type(csv_file["Biology"]) isse hum check kar sakte hai ki csv_file["Biology"] ka data type kya hai
type(csv_file["Biology"])
# Out:
# pandas.core.series.Series

# %%
#jab kabhi ek se jyada column ko dekhna ho to hum un column ka naam likh ke usko access kar sakte hai
#csv_file[["Maths" ,"Biology"]] se hum Maths aur Biology column ko access kar sakte hai
csv_file[["Maths" ,"Biology"]]
# Out:
#    Maths  Biology
# 0     55       21
# 1     75       90
# 2     25       95
# 3     78       54
# 4     58       96
# 5     45       55
# 6     55       75
# 7     54       25
# 8     55       78
# 9     96       58

# %%
#jab kabhi ek se jyada column ho tab wo ek pandas dataframe ban jayega
type(csv_file[["Maths" ,"Biology"]])
# Out:
# pandas.core.frame.DataFrame
