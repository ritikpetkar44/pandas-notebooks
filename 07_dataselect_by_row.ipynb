# %% [markdown]
# SELECT DATA BY ROWS

# %%
import pandas as pd

# %%
#ye ek csv file hai jisse hum read kar rahe hai
csv_file = pd.read_csv("G:\downloads\student_marks.csv")

# %%
#iloc se hum row ke index ke hisab se data ko access kar sakte hai, yaha pe 0 index wali row ko access kar rahe hai
csv_file.iloc[0]
