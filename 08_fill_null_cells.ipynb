# %% [markdown]
# Fill the nun element in the datafile

# %%
import pandas as pd

# %%
#ye ek csv file hai jisse hum read kar rahe hai
csv_file = pd.read_csv("G:\downloads\student_marks.csv")

# %%
print(csv_file)
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  Biology
# 0       John      M  05-04-1988    NaN     45.0       56.0     21.0
# 1     Suresh      M  04-05-1987   75.0      NaN       78.0     90.0
# 2     Ramesh      M  25-05-1989   25.0     54.0        NaN     95.0
# 3    Jessica      F  12-08-1990   78.0     96.0       86.0      NaN
# 4   Jennifer      F  02-09-1989   58.0     96.0       78.0      NaN
# 5       Annu      F  05-04-1988   45.0     87.0        NaN     55.0
# 6      pooja      F  04-05-1987   55.0      NaN       61.0     75.0
# 7     Ritesh      M  25-05-1989    NaN     76.0       87.0     25.0
# 8      Farha      F  12-08-1990   55.0     63.0       89.0     78.0
# 9     Mukesh      M  02-09-1989   96.0     46.0       77.0     58.0

# %%
# delete nhi karnihai to fill kar sakte hai
# csv_file.fillna(0)
csv1=csv_file.fillna(0)
print(csv1)
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  Biology
# 0       John      M  05-04-1988    0.0     45.0       56.0     21.0
# 1     Suresh      M  04-05-1987   75.0      0.0       78.0     90.0
# 2     Ramesh      M  25-05-1989   25.0     54.0        0.0     95.0
# 3    Jessica      F  12-08-1990   78.0     96.0       86.0      0.0
# 4   Jennifer      F  02-09-1989   58.0     96.0       78.0      0.0
# 5       Annu      F  05-04-1988   45.0     87.0        0.0     55.0
# 6      pooja      F  04-05-1987   55.0      0.0       61.0     75.0
# 7     Ritesh      M  25-05-1989    0.0     76.0       87.0     25.0
# 8      Farha      F  12-08-1990   55.0     63.0       89.0     78.0
# 9     Mukesh      M  02-09-1989   96.0     46.0       77.0     58.0

# %%
#hum dekh sakte hai ki is csv file me kitne null values hai
# so, ab hum in null values wale rows ko drop kar denge
#aur drop karne ke baad hum dekh sakte hai ki null values wale rows delete ho gaye hai
csv2=csv_file.dropna()
print(csv2)
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  Biology
# 8      Farha      F  12-08-1990   55.0     63.0       89.0     78.0
# 9     Mukesh      M  02-09-1989   96.0     46.0       77.0     58.0
