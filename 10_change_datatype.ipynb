# %% [markdown]
# Change data type in our datafile

# %%
import pandas as pd

# %%
#ye ek csv file hai jisse hum read kar rahe hai
csv_file = pd.read_csv("G:\downloads\student_marks.csv")
print(csv_file)
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  Biology
# 0       John      M  05-04-1988     10       45         56       21
# 1     Suresh      M  04-05-1987     75       11         78       90
# 2     Ramesh      M  25-05-1989     25       54         44       95
# 3    Jessica      F  12-08-1990     78       96         86       89
# 4   Jennifer      F  02-09-1989     58       96         78       79
# 5       Annu      F  05-04-1988     45       87         45       55
# 6      pooja      F  04-05-1987     55       55         61       75
# 7     Ritesh      M  25-05-1989     55       76         87       25
# 8      Farha      F  12-08-1990     55       63         89       78
# 9     Mukesh      M  02-09-1989     96       46         77       58

# %%
#hum columns ka datatype easliy change kar sakte hai
csv1=csv_file.astype({"Maths": "float"})
print(csv1)
csv1.info()
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  Biology
# 0       John      M  05-04-1988   10.0       45         56       21
# 1     Suresh      M  04-05-1987   75.0       11         78       90
# 2     Ramesh      M  25-05-1989   25.0       54         44       95
# 3    Jessica      F  12-08-1990   78.0       96         86       89
# 4   Jennifer      F  02-09-1989   58.0       96         78       79
# 5       Annu      F  05-04-1988   45.0       87         45       55
# 6      pooja      F  04-05-1987   55.0       55         61       75
# 7     Ritesh      M  25-05-1989   55.0       76         87       25
# 8      Farha      F  12-08-1990   55.0       63         89       78
# 9     Mukesh      M  02-09-1989   96.0       46         77       58
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
# ...
