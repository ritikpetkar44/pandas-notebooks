# %% [markdown]
# How to add column on our datafile

# %%
import pandas as pd
#ye ek csv file hai jisse hum read kar rahe hai
csv_file = pd.read_csv("G:\downloads\student_marks.csv")
print(csv_file)
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  Biology
# 0       John      M  05-04-1988     10       45         56       21
# 1     Suresh      M  04-05-1987     75       11         78       90
# 2     Ramesh      M  25-05-1989     25       54         44       95
# 3    Jessica      F  12-08-1990     78       96         86       89
# 4   Jennifer      F  02-09-1989     58       96         78       79
# 5       Annu      F  05-04-1988     45       87         45       55
# 6      pooja      F  04-05-1987     55       55         61       75
# 7     Ritesh      M  25-05-1989     55       76         87       25
# 8      Farha      F  12-08-1990     55       63         89       78
# 9     Mukesh      M  02-09-1989     96       46         77       58

# %%
#agar hume ek new column add karna hai to hum aise kar sakte hai
csv_file["Total Marks"] = csv_file["Maths"] + csv_file["Physics"] + csv_file["Biology"]+ csv_file["Chemistry"]
print(csv_file)
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  Biology  \
# 0       John      M  05-04-1988     10       45         56       21
# 1     Suresh      M  04-05-1987     75       11         78       90
# 2     Ramesh      M  25-05-1989     25       54         44       95
# 3    Jessica      F  12-08-1990     78       96         86       89
# 4   Jennifer      F  02-09-1989     58       96         78       79
# 5       Annu      F  05-04-1988     45       87         45       55
# 6      pooja      F  04-05-1987     55       55         61       75
# 7     Ritesh      M  25-05-1989     55       76         87       25
# 8      Farha      F  12-08-1990     55       63         89       78
# 9     Mukesh      M  02-09-1989     96       46         77       58
#
#    Total Marks
# 0          132
# 1          254
# 2          218
# 3          349
# 4          311
# 5          232
# 6          246
# 7          243
# 8          285
# 9          277

# %%
#isse aapfunction bna ke bhi kar sakte hai
"""
def total_marks(row):
    return row["Maths"] + row["Physics"] + row["Biology"]+ row["Chemistry"]
csv_file["Total Marks"] = csv_file.apply(total_marks, axis=1)
"""
#-----------------------------------------------------------------------
csv_file["Average"] = csv_file["Total Marks"]/4
print(csv_file)
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  Biology  \
# 0       John      M  05-04-1988     10       45         56       21
# 1     Suresh      M  04-05-1987     75       11         78       90
# 2     Ramesh      M  25-05-1989     25       54         44       95
# 3    Jessica      F  12-08-1990     78       96         86       89
# 4   Jennifer      F  02-09-1989     58       96         78       79
# 5       Annu      F  05-04-1988     45       87         45       55
# 6      pooja      F  04-05-1987     55       55         61       75
# 7     Ritesh      M  25-05-1989     55       76         87       25
# 8      Farha      F  12-08-1990     55       63         89       78
# 9     Mukesh      M  02-09-1989     96       46         77       58
#
#    Total Marks  Average
# 0          132    33.00
# 1          254    63.50
# 2          218    54.50
# 3          349    87.25
# 4          311    77.75
# 5          232    58.00
# 6          246    61.50
# ...
