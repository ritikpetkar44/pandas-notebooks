# %% [markdown]
# join Two DataFrame

# %%
import pandas as pd

# %% [markdown]
# Hum 2 dataframe ko jod sakte hai

# %%
#1st data frame
df1= pd.DataFrame({
    "student": ['Alice', 'Bob', 'Charlie'],
    "grade": [85, 92, 78]
},
index=['I', 'II', 'III'])
print(df)
# Out:
#      student  grade
# I      Alice     85
# II       Bob     92
# III  Charlie     78

# %%
#2nd data frame
df2= pd.DataFrame({
    "student": ["dave", "eve", "frank"],
    "grade": [88, 90, 82    ]
},
index=['I', 'II', 'III'])
print(df2)
# Out:
#     student  grade
# I      dave     88
# II      eve     90
# III   frank     82

# %%
#pandas me hum 2 data frame ko merge kar sakte hain. 
#Merge karne ke liye hum pandas ke merge function ka use karte hain.
#code: pd.concat([df1, df2])
df3=pd.concat([df1, df2])
print(df3)
# Out:
#      student  grade
# I      Alice     85
# II       Bob     92
# III  Charlie     78
# I       dave     88
# II       eve     90
# III    frank     82

# %%
#merging the data frames
#merge  hum kisi bhi column ke basis pe kar sakte hain.
df4=pd.DataFrame({
    "student": ['Alice', 'Bob', 'Charlie', 'dave', 'eve', 'frank'],
    "roll_no": [100, 200, 300, 400, 500, 600]
})
print(df4)
# Out:
#    student  roll_no
# 0    Alice      100
# 1      Bob      200
# 2  Charlie      300
# 3     dave      400
# 4      eve      500
# 5    frank      600

# %%
#yaha humne df3 aur df4 ko student column ke basis pe merge kiya hai.
#yaha hum bs student column ko merge kar rahe hain.
merged_df= pd.merge(df3, df4, on="student", how="inner")
print(merged_df)
# Out:
#    student  grade  roll_no
# 0    Alice     85      100
# 1      Bob     92      200
# 2  Charlie     78      300
# 3     dave     88      400
# 4      eve     90      500
# 5    frank     82      600
