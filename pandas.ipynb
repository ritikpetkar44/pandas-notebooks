# %%
import pandas as pd
print("its create pandas dataframe")
yash =pd.DataFrame({"student":["rahul","yash","vishesh"],"USN":["CM25118","CM25126","CM25124"],"Marks":[ 56,68,86],"result":["fail","pass","pass"],}, index=['1','2','3'] )
print(yash)
# Out:
# its create pandas dataframe
#    student      USN  Marks result
# 1    rahul  CM25118     56   fail
# 2     yash  CM25126     68   pass
# 3  vishesh  CM25124     86   pass

# %%
df=pd.read_csv("G:\downloads\student_marks.csv")

# %%
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(df)
#
# NameError: name 'df' is not defined
